# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Prepare Agent and Configs

# %%
import os
import uuid
from agent import Agent

os.environ['TAVILY_API_KEY'] = "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"
os.environ['COHERE_API_KEY'] = 'KM009720agM7fxDcpaGtnNO0aQKvfXCBsT52N6xN'

agent = Agent()

# %%
from Assistants_Workflow import final_graph

# %%
from IPython.display import Image, display

try:
    display(Image(final_graph.get_graph(xray=True).draw_mermaid_png()))
except:
    # This requires some extra dependencies and is optional
    pass

# %%
passenger_id = '3442 587242'

config = {
    'configurable': {
        'passenger_id': passenger_id,
        'thread_id': str(uuid.uuid4()),
    }
}

# %%
# question = "show me the defult information you know about me?"
question = "اطلاعات پیش فرضی را که درباره من می دانید به من نشان دهید؟"
agent.run(question, config, _graph=final_graph, clear_message_history=False, reset_db=True)
# Out:
# ================================ Human Message =================================
#
# اطلاعات پیش فرضی را که درباره من می دانید به من نشان دهید؟
# {'messages': [HumanMessage(content='اطلاعات پیش فرضی را که درباره من می دانید به من نشان دهید؟', id='2494e052-3615-4bb2-8344-e271fcd9ab8f')], 'user_info': 'Item 1:\n-- ticket_no: 7240005432906569\n-- book_ref: C46E9F\n-- flight_id: 19250\n-- flight_no: LX0112\n-- departure_airport: CDG\n-- arrival_airport: BSL\n-- scheduled_departure: 2024-05-28 21:01:16.314693-04:00\n-- scheduled_arrival: 2024-05-28 22:31:16.314693-04:00\n-- seat_no: 18E\n-- fare_conditions: Economy\n', 'dialog_state': []}
# ================================== Ai Message ==================================
#
# ...

# %%
question = "what tools do you have to help customers?"
agent.run(question, config, _graph=final_graph, clear_message_history=False, reset_db=True)
# Out:
# ================================ Human Message =================================
#
# what tools do you have to help customers?
# ...

# %%
question = "find my flight and cancel it, continue your task until ticket canceled successfully"
agent.run(question, config, _graph=final_graph, clear_message_history=False, reset_db=True)
# Out:
# ================================ Human Message =================================
#
# find my flight and cancel it, continue your task until ticket canceled successfully
# {'messages': [HumanMessage(content='find my flight and cancel it, continue your task until ticket canceled successfully', id='327dec6e-257b-477c-b0b4-e7d7bf0daab4')], 'user_info': 'Item 1:\n-- ticket_no: 7240005432906569\n-- book_ref: C46E9F\n-- flight_id: 19250\n-- flight_no: LX0112\n-- departure_airport: CDG\n-- arrival_airport: BSL\n-- scheduled_departure: 2024-05-28 15:36:46.354812-04:00\n-- scheduled_arrival: 2024-05-28 17:06:46.354812-04:00\n-- seat_no: 18E\n-- fare_conditions: Economy\n', 'dialog_state': []}
# ================================== Ai Message ==================================
#
# ```json
# {
#     "THOUGHT": "I need to find the user's flight and then transfer the request to the specialized assistant to cancel the flight booking.",
#     "ACTION": "fetch_user_flight_information_tool",
# ...

# %%
passenger_id = '3442 587242'

config = {
    'configurable': {
        'passenger_id': passenger_id,
        'thread_id': str(uuid.uuid4()),
    }}
# question = "find my flight and cancel it, continue your task until ticket canceled successfully"
question = "پرواز من را لغو کنید"
agent.run(question, config, _graph=final_graph, clear_message_history=False, reset_db=True)
# Out:
# ================================ Human Message =================================
#
# پرواز من را لغو کنید
# {'messages': [HumanMessage(content='پرواز من را لغو کنید', id='fb852777-4b8b-4900-bf93-7dc65fbfbc83')], 'user_info': 'Item 1:\n-- ticket_no: 7240005432906569\n-- book_ref: C46E9F\n-- flight_id: 19250\n-- flight_no: LX0112\n-- departure_airport: CDG\n-- arrival_airport: BSL\n-- scheduled_departure: 2024-05-28 21:27:03.486929-04:00\n-- scheduled_arrival: 2024-05-28 22:57:03.486929-04:00\n-- seat_no: 18E\n-- fare_conditions: Economy\n', 'dialog_state': []}
# ================================== Ai Message ==================================
#
# ```json
# {
#     "THOUGHT": "The user is requesting to cancel their flight. I will transfer this request to the appropriate assistant.",
#     "ACTION": "ToFlightBookingAssistant",
#     "ACTION_PARAMS": {
#         "request": "Cancel my flight, please."
#     }
# }
# ```
# Tool Calls:
# ...

# %%
passenger_id = '3442 587242'

config = {
    'configurable': {
        'passenger_id': passenger_id,
        'thread_id': str(uuid.uuid4()),
    }}

# %%
question = "choose one of the next week's flights for me"
agent.run(question, config, _graph=final_graph, clear_message_history=False, reset_db=True)
# Out:
# ================================ Human Message =================================
#
# choose one of the next week's flights for me
# {'messages': [HumanMessage(content="choose one of the next week's flights for me", id='52b8a200-9438-4b2b-819a-3ad0c5952af1')], 'user_info': 'Item 1:\n-- ticket_no: 7240005432906569\n-- book_ref: C46E9F\n-- flight_id: 19250\n-- flight_no: LX0112\n-- departure_airport: CDG\n-- arrival_airport: BSL\n-- scheduled_departure: 2024-05-28 22:07:04.999595-04:00\n-- scheduled_arrival: 2024-05-28 23:37:04.999595-04:00\n-- seat_no: 18E\n-- fare_conditions: Economy\n', 'dialog_state': []}
# ['ToFlightBookingAssistant', 'tavily_search_tool', 'lookup_policy_tool']
# ================================== Ai Message ==================================
#
# ```json
# {
#     "THOUGHT": "I need to delegate this request to the flight booking assistant to choose a flight for next week.",
#     "ACTION": "ToFlightBookingAssistant",
#     "ACTION_PARAMS": {
# ...

# %%
passenger_id = '3442 587242'

config = {
    'configurable': {
        'passenger_id': passenger_id,
        'thread_id': str(uuid.uuid4()),
    }
}
question = "جستجو کن ببین اقای مصطفی نوشابه ای کیه"
agent.run(question, config, _graph=final_graph, clear_message_history=False, reset_db=True)
# Out:
# ================================ Human Message =================================
#
# جستجو کن ببین اقای مصطفی نوشابه ای کیه
# {'messages': [HumanMessage(content='جستجو کن ببین اقای مصطفی نوشابه ای کیه', id='6ce6ea2a-2033-4a11-8920-375db2b18023')], 'user_info': 'Item 1:\n-- ticket_no: 7240005432906569\n-- book_ref: C46E9F\n-- flight_id: 19250\n-- flight_no: LX0112\n-- departure_airport: CDG\n-- arrival_airport: BSL\n-- scheduled_departure: 2024-05-28 22:10:20.242060-04:00\n-- scheduled_arrival: 2024-05-28 23:40:20.242060-04:00\n-- seat_no: 18E\n-- fare_conditions: Economy\n', 'dialog_state': []}
# ['ToFlightBookingAssistant', 'tavily_search_tool', 'lookup_policy_tool']
# ================================== Ai Message ==================================
#
# ```json
# {
#     "THOUGHT": "I will search for information about Mr. Mustafa Nooshabehi.",
#     "ACTION": "tavily_search_tool",
#     "ACTION_PARAMS": {
#         "query": "Who is Mr. Mustafa Nooshabehi?"
#     }
# }
# ```
# ...
