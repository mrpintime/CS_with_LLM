# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Prepare Agent and Configs

# %%
import os
import uuid
from agent import Agent
# from agent import empty

os.environ['TAVILY_API_KEY'] = "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"
os.environ['COHERE_API_KEY'] = 'KM009720agM7fxDcpaGtnNO0aQKvfXCBsT52N6xN'

agent = Agent()

# %%
passenger_id = '3442 587242'

config = {
    'configurable': {
        'passenger_id': passenger_id,
        'thread_id': str(uuid.uuid4()),
    }
}

# %%
question = "what tools do you have access to?"
agent.run(question, config, clear_message_history=False, reset_db=True)
# Out:
# ================================ Human Message =================================
#
# what tools do you have access to?
# ================================== Ai Message ==================================
#
# ```json
# {
#     "THOUGHT": "The user is asking about the tools that I have access to as Iran Airlines' customer support assistant.",
#     "FINAL_ANSWER": "I have access to various tools to assist you with your travel plans and inquiries. Here is a list of the tools at my disposal:\n- Flight search tool\n- Policy lookup tool\n- User flight information tool\n- Car rental search and booking tool\n- Trip recommendation search and booking tool\n- Hotel search and booking tool\n- And more!\nFeel free to ask me about any travel-related queries or concerns you may have, and I will do my best to assist you using the tools available."
# }
# ```
# ================================== Ai Message ==================================
#
# ```json
# {
# ...

# %%
question = "what excursion tools do you have?"
agent.run(question, config, clear_message_history=False, reset_db=True)
# Out:
# ================================ Human Message =================================
#
# what excursion tools do you have?
# ================================== Ai Message ==================================
#
# ```json
# {
#     "THOUGHT": "The user is asking about the tools available for excursions or trip recommendations.",
#     "FINAL_ANSWER": "I have access to a trip recommendation search tool that can provide suggestions for excursions and activities based on your preferences. This tool allows me to search for recommendations based on location, activity type, or specific keywords. If you're interested in booking an excursion, I can also assist with that process using the booking tool. Additionally, if you've already booked an excursion and need to make updates or cancellations, I have access to the necessary tools for those as well."
# }
# ```
# ================================== Ai Message ==================================
#
# ```json
# {
# ...

# %%
question = "what do you know about me by defults?"
agent.run(question, config, clear_message_history=False)
# Out:
# ================================ Human Message =================================
#
# what do you know about me by defults?
# ================================== Ai Message ==================================
#
# ```json
# {
#     "THOUGHT": "The user is asking about the default information that is known about them.",
#     "FINAL_ANSWER": "By default, I have access to your current travel itinerary, which includes the following information:\n- Ticket number: 7240005432906569\n- Booking reference: C46E9F\n- Flight ID: 19250\n- Flight number: LX0112\n- Departure airport: CDG (Paris Charles de Gaulle Airport)\n- Arrival airport: BSL (Basel Airport)\n- Scheduled departure time: May 28, 2024, at 20:25\n- Scheduled arrival time: May 28, 2024, at 21:55\n- Seat number: 18E\n- Fare conditions: Economy\nAdditionally, I have access to tools that can provide further information about your flight, such as departure and arrival gates, as well as any changes or updates to your itinerary."
# }
# ```
# ...

# %%
question = "change my flight to one of the next week flights please choose new_flight_id by yourself and stop when update was successfully"
agent.run(question, config, clear_message_history=False)
# Out:
# ================================ Human Message =================================
#
# change my flight to one of the next week flights please choose new_flight_id by yourself and stop when update was successfully
# ================================== Ai Message ==================================
#
# ```json
# {
#     "THOUGHT": "I will search for flights with the same route as the user's original flight, but departing sometime next week. Once I find an appropriate flight, I will update the user's ticket to the new flight.",
#     "ACTION": "search_flights_tool",
#     "ACTION_PARAMS": {
#         "departure_airport": "CDG",
#         "arrival_airport": "BSL",
#         "start_time": "2024-06-01",
#         "end_time": "2024-06-07"
#     }
# }
# ```
# Tool Calls:
#   search_flights_tool (9a0a2c79-7615-4539-af4b-5ce646466b5f)
#  Call ID: 9a0a2c79-7615-4539-af4b-5ce646466b5f
#   Args:
#     departure_airport: CDG
#     arrival_airport: BSL
#     start_time: 2024-06-01
# ...

# %%
question = "بر اساس اطلاعات پرواز من، پیشنهاداتی در مورد ماشین و اجاره ماشین به من بدهید"
agent.run(question, config, clear_message_history=False)
# Out:
# ================================ Human Message =================================
#
# بر اساس اطلاعات پرواز من، پیشنهاداتی در مورد ماشین و اجاره ماشین به من بدهید
# ================================== Ai Message ==================================
#
# ```json
# {
#  "THOUGHT": "I will search for car rental options near the user's arrival airport, Basel (BSL), Switzerland, for their travel dates.",
#  "ACTION": "search_car_rentals_tool",
#  "ACTION_PARAMS": {
#  "location": "Basel, Switzerland",
#  "start_date": "2024-05-28",
#  "end_date": "2024-06-02",
#  "price_tier": "Economy"
#  }
# }
# ```
# Tool Calls:
#   search_car_rentals_tool (34e44fb0-6585-4e92-9118-f3c7f4fd42f4)
#  Call ID: 34e44fb0-6585-4e92-9118-f3c7f4fd42f4
#   Args:
#     location: Basel, Switzerland
#     start_date: 2024-05-28
#     end_date: 2024-06-02
#     price_tier: Economy
# ================================= Tool Message =================================
# Name: search_car_rentals_tool
#
#
# ...

# %%
question = "Based on my flight data can you update my flight to nearest possible flight"
agent.run(question, config, clear_message_history=False)
# Out:
# ================================ Human Message =================================
#
# Based on my flight data can you update my flight to nearest possible flight
# ================================== Ai Message ==================================
#
# ```json
# {
#  "THOUGHT": "I need to search for flights departing from CDG (Paris Charles de Gaulle Airport) and arriving at BSL (Basel Airport) that are closest to the user's scheduled departure time of May 28, 2024, at 20:25. Once I have found suitable alternatives, I will need to perform another action to update the user's ticket to the new flight.",
#  "ACTION": "search_flights_tool",
#  "ACTION_PARAMS": {
#  "departure_airport": "CDG",
#  "arrival_airport": "BSL",
#  "start_time": "2024-05-28T20:25:00-04:00",
#  "end_time": "2024-05-28T22:25:00-04:00"
#  }
# }
# ```
# Tool Calls:
#   search_flights_tool (2e24a123-1dc1-4af0-8cef-7bad56b4a913)
#  Call ID: 2e24a123-1dc1-4af0-8cef-7bad56b4a913
#   Args:
#     departure_airport: CDG
# ...

# %%
passenger_id = '3442 587242'

config = {
    'configurable': {
        'passenger_id': passenger_id,
        'thread_id': str(uuid.uuid4()),
    }
}

question = "سلام. اطلاعات مربوط به پروازم رو میخواستم دریافت کنم."
agent.run(question, config, clear_message_history=False)
# Out:
# ================================ Human Message =================================
#
# سلام. اطلاعات مربوط به پروازم رو میخواستم دریافت کنم.
# ================================== Ai Message ==================================
#
# ```json
# {
#     "THOUGHT": "I will fetch the user's flight information and provide it in Persian.",
#     "FINAL_ANSWER": "سلام! اطلاعات پرواز شما به شرح زیر است:\n\nشماره بلیط: 7240005432906569\nشماره رزرو: C46E9F\nشماره پرواز: 19250\nشماره پرواز: LX0112\nفرودگاه مبدا: CDG\nفرودگاه مقصد: BSL\nساعت حرکت برنامه ریزی شده: 20:39\nساعت ورود برنامه ریزی شده: 22:09\nشماره صندلی: 18E\nشرایط نرخ: Economy"
# }
# ```
# ================================== Ai Message ==================================
#
# ```json
# {
#     "THOUGHT": "The user has requested a translation of the provided text into Persian.",
# ...

# %%
passenger_id = '3442 587242'

config = {
    'configurable': {
        'passenger_id': passenger_id,
        'thread_id': str(uuid.uuid4()),
    }
}

# %%
question = "اول ببین پروازم به چه مقصدی هستش سپس اطلاعات پرواز های هفته بعد به اونجا رو بده"
agent.run(question, config, clear_message_history=False)
# Out:
# ================================ Human Message =================================
#
# اول ببین پروازم به چه مقصدی هستش سپس اطلاعات پرواز های هفته بعد به اونجا رو بده
# ================================== Ai Message ==================================
#
# ```json
# {
#  "THOUGHT": "I need to first check the user's current flight destination and then find flights to that destination for next week.",
#  "ACTION": "fetch_user_flight_information_tool",
#  "ACTION_PARAMS": {}
# }
# ```
# Tool Calls:
#   fetch_user_flight_information_tool (e456263c-26d4-4a23-97f8-bcb4f53404a5)
#  Call ID: e456263c-26d4-4a23-97f8-bcb4f53404a5
#   Args:
# ================================= Tool Message =================================
# Name: fetch_user_flight_information_tool
#
# Item 1:
# -- ticket_no: 7240005432906569
# -- book_ref: C46E9F
# -- flight_id: 19250
# -- flight_no: LX0112
# -- departure_airport: CDG
# -- arrival_airport: BSL
# -- scheduled_departure: 2024-05-28 20:56:50.962103-04:00
# ...

# %%
question = "اطلاعات کلی درمورد هتل های مقصد پروازم رو میخواستم"
agent.run(question, config, clear_message_history=False)
# Out:
# ================================ Human Message =================================
#
# اطلاعات کلی درمورد هتل های مقصد پروازم رو میخواستم
# ================================== Ai Message ==================================
#
# ```json
# {
#  "THOUGHT": "I need to find general information about hotels in the user's flight destination, Basel.",
#  "ACTION": "search_hotels_tool",
#  "ACTION_PARAMS": {
#  "location": "Basel",
#  "name": null,
#  "price_tier": null,
#  "checkin_date": null,
#  "checkout_date": null
#  }
# }
# ```
# Tool Calls:
#   search_hotels_tool (0c7190d1-889c-4c9c-90e4-573478f4385a)
#  Call ID: 0c7190d1-889c-4c9c-90e4-573478f4385a
#   Args:
#     location: Basel
#     name: None
#     price_tier: None
#     checkin_date: None
#     checkout_date: None
# ================================= Tool Message =================================
# Name: search_hotels_tool
#
# Item 1:
# -- id: 1
# -- name: Hilton Basel
# -- location: Basel
# -- price_tier: Luxury
# ...
